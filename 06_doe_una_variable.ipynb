# %% [markdown]
# # Diseño de experimento
#
# El diseño de experimentos en el entrenamiento de redes neuronales juega un papel crucial en la optimización del rendimiento del modelo. Este enfoque sistemático permite explorar y ajustar los hiperparámetros (como la tasa de aprendizaje, el número de capas y neuronas, y el tamaño del lote) de manera eficiente y efectiva. Al planificar y estructurar los experimentos, se pueden identificar las combinaciones óptimas de hiperparámetros que mejoran la precisión y la generalización del modelo, mientras se minimiza el tiempo y los recursos computacionales necesarios. Además, un buen diseño de experimentos reduce el impacto ecológico del entrenamiento de redes neuronales al disminuir el número de ejecuciones necesarias, optimizando así el consumo de energía y hardware.
#
# ## Una variable a la vez
#
# El enfoque de diseño de experimentos de una variable a la vez (One Variable At a Time, OVAT) es una metodología simple en la que se varía un solo factor o variable experimental mientras se mantienen constantes todos los demás factores. Este enfoque permite observar cómo cambios en esa única variable afectan el resultado del experimento.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/irvingvasquez/practicas_pytorch/blob/master/06_doe_una_variable.ipynb)
#
# Si ejecutas en COLAB debes copiar los archivos extra de este repositorio.
#
# @juan1rving

# %%
# Cargamos paquetes necesarios

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms

#Types
from torch.utils.data import DataLoader, Dataset
from typing import Dict, Tuple, Union
from torch import optim, nn

#helper was developed by Udacity under MIT license
import helper

# %% [markdown]
# ### 1. Definición de variables y rango de valores:
#
# Identificar los factores o variables experimentales clave que se desean estudiar. En el contexto de redes neuronales, estas variables pueden incluir la tasa de aprendizaje, el número de capas, el número de neuronas por capa, el tamaño del lote, entre otros.
#
# Variables que tomaremos en cuenta:
#
# - Tasa de aprendizaje (eta)
# - Número de épocas (n_epocas)
# - Tamaño de lote (batch_size)
#
# Una vez definidas las variables independientes definimos un rango de valores posibles para cada variable.
#
# > TODO: Define un rango de valores posibles para cada variable. Incluye el valor mínimo y el valor máximo. Se sugiere utilizar una lista de valores obtenida con una separación uniforme. Probar almenos 5 valores por variable.

# %%
hyperparameter_range = {
    'eta' : [1e-4, 3e-4, 1e-3, 3e-3, 1e-2],
    'epochs' : [1, 2, 3, 4, 5],
    'batch_size' : [16, 32, 64, 128, 256]
}

# %% [markdown]
# ### 2. Configuración inicial:
#
# Establecer una configuración inicial para la red neuronal con valores predeterminados para todos los hiperparámetros.
#
# > TODO: Define la configuración inicial. Se sugiere usar un diccionario para contener dicha configuración.

# %%
configuration = {
    'eta': 0.001,
    'epochs': 1,
    'batch_size': 32
}

best_configuration = {
    'eta': None,
    'epochs': None,
    'batch_size': None
}

best_accuracy = {
    'eta': float('-inf'),
    'epochs': float('-inf'),
    'batch_size': float('-inf')
}

# %% [markdown]
# ### 3. Variación de una variable a la vez:
#
# - Seleccionar la primera variable a estudiar (por ejemplo, la tasa de aprendizaje).
# - Realizar una serie de experimentos donde se varía únicamente la tasa de aprendizaje, mientras se mantienen constantes todos los demás hiperparámetros.
# - Registrar el rendimiento del modelo para cada valor de la tasa de aprendizaje.
#
# > TODO: Modifica el código para que pueda aceptar la configuración deseada

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5), (0.5))])
trainset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=True, transform=transform)
validationset = datasets.FashionMNIST('F_MNIST_data/', download=True, train=False, transform=transform)

# %%
class RedNeuronal(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers, drop_p = 0.5):
        '''
        Construye una red de tamaño arbitrario.
        
        Parámetros:
        input_size: cantidad de elementos en la entrada
        output_size: cantidada de elementos en la salida 
        hidden_layers: cantidad de elementos por cada capa oculta
        drop_p: probabilidad de "tirar" (drop) una neurona [0,1] 
        '''
        # llamamos al constructor de la superclase
        super().__init__()
        
        # Agregamos la primera capa
        self.hidden_layers = nn.ModuleList([nn.Linear(input_size, hidden_layers[0])])
        
        # agregamos cada una de las capas, zip empareja el número de entradas con las salidas
        layer_sizes = zip(hidden_layers[:-1], hidden_layers[1:])
        self.hidden_layers.extend([nn.Linear(h1, h2) for h1, h2 in layer_sizes])
        
        # agregamos la capa de salida final de la red
        self.output = nn.Linear(hidden_layers[-1], output_size)
        
        # Incluimos drop-out en la red
        self.dropout = nn.Dropout(p=drop_p)
        
    def forward(self, x):
        ''' Pase hacia adelante en la red, el regreso son las probabilidades en el dominio log '''
        
        # Hacemos un pase frontal en cada una de las capas ocultas, 
        # La funció de activación es un RELU combinado con dropout
        for linear in self.hidden_layers:
            x = F.relu(linear(x))
            x = self.dropout(x)
        
        x = self.output(x)
        
        return F.log_softmax(x, dim=1)

# %%
# Create the network, define the criterion and optimizer
model = RedNeuronal(784, 10, [516, 256], drop_p=0.5)
criterion = nn.NLLLoss()

# %%
def get_hyperparameters(
    configuration: Dict[str, Union[float, int]],
    model: nn.Module,
    trainset: Dataset,
    validationset: Dataset
) -> Tuple[optim.Optimizer, int, DataLoader, DataLoader]:

    batch_size = configuration["batch_size"]
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
    validationloader = DataLoader(validationset, batch_size=batch_size, shuffle=True)
    optimizer = optim.Adam(model.parameters(), lr=configuration["eta"])

    return optimizer, configuration["epochs"], trainloader, validationloader

# %%
# Implementamos una función de evaluación
def validation(model, validationloader, criterion):
    test_loss = 0
    accuracy = 0
    for images, labels in validationloader:

        images.resize_(images.shape[0], 784)

        output = model.forward(images)
        test_loss += criterion(output, labels).item()

        ps = torch.exp(output)
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy += equality.type(torch.FloatTensor).mean()
    
    return test_loss, accuracy

# %%
def train_model(model: nn.Module, optimizer : optim.Optimizer, epochs : int, trainloader : DataLoader, validationloader :  DataLoader, criterion):
    steps = 0
    running_loss = 0
    print_every = 40
    for e in range(epochs):
    # Cambiamos a modo entrenamiento
        model.train()
        for images, labels in trainloader:
            steps += 1
    
            # Aplanar imágenes a un vector de 784 elementos
            images.resize_(images.size()[0], 784)
            
            optimizer.zero_grad()
            
            output = model.forward(images)
            loss = criterion(output, labels)
            # Backprogamation
            loss.backward()
            # Optimización
            optimizer.step()
            
            running_loss += loss.item()
            
            if steps % print_every == 0:
                # Cambiamos a modo de evaluación
                model.eval()
                
                # Apagamos los gradientes, reduce memoria y cálculos
                with torch.no_grad():
                    test_loss, accuracy = validation(model, validationloader, criterion)
                    
                print("Epoch: {}/{}.. ".format(e+1, epochs),
                    "Pérdida de entrenamiento: {:.3f}.. ".format(running_loss/print_every),
                    "Pérdida de validación: {:.3f}.. ".format(test_loss/len(validationloader)),
                    "Exactitud de validación: {:.3f}".format(accuracy/len(validationloader)))
                
                running_loss = 0
                
                # Make sure training is back on
                model.train()

# %%
def reset_weights(m):
    if hasattr(m, "reset_parameters"):
        m.reset_parameters()

# %%
experiments = []
id_of_experiment = 0

for hyper_name, values in hyperparameter_range.items():

    print(f"\n>>> Probando hiperparámetro: {hyper_name}")
    print(f"Valores a probar: {values}\n")

    for value in values:
        print(f"  - Probando {hyper_name} = {value}")

        configuration[hyper_name] = value
        model.apply(reset_weights)
        
        optimizer, epochs, trainloader, validationloader = get_hyperparameters(
            configuration=configuration,
            model=model,
            trainset=trainset,
            validationset=validationset
        )

        train_model(
            optimizer = optimizer, 
            epochs = epochs, 
            trainloader = trainloader, 
            validationloader = validationloader,
            criterion = criterion
        )
        
        test_loss, test_accuracy = validation(
            model=model,
            validationloader=validationloader,
            criterion=criterion
        )

        print(f"    -> Accuracy obtenida: {test_accuracy:.4f}")

        experiments.append({
            "id_of_experiment": id_of_experiment,
            "eta": configuration["eta"],
            "epochs": configuration["epochs"],
            "batch_size": configuration["batch_size"],
            "accuracy": test_accuracy
        })

        if test_accuracy > best_accuracy[hyper_name]:
            best_accuracy[hyper_name] = test_accuracy
            best_configuration[hyper_name] = value
            print(f"    * Nuevo mejor valor encontrado para {hyper_name}: {value}")

        id_of_experiment += 1

    print(f"\n>>> Mejor valor para {hyper_name}: {best_configuration[hyper_name]}")
    configuration[hyper_name] = best_configuration[hyper_name]
# Out:
# Epoch: 1/1..  Pérdida de entrenamiento: 2.117..  Pérdida de validación: 1.858..  Exactitud de validación: 0.578
# Epoch: 1/1..  Pérdida de entrenamiento: 1.663..  Pérdida de validación: 1.324..  Exactitud de validación: 0.645
# Epoch: 1/1..  Pérdida de entrenamiento: 1.270..  Pérdida de validación: 1.034..  Exactitud de validación: 0.658
# Epoch: 1/1..  Pérdida de entrenamiento: 1.109..  Pérdida de validación: 0.892..  Exactitud de validación: 0.710
# Epoch: 1/1..  Pérdida de entrenamiento: 0.972..  Pérdida de validación: 0.815..  Exactitud de validación: 0.727
# Epoch: 1/1..  Pérdida de entrenamiento: 0.920..  Pérdida de validación: 0.768..  Exactitud de validación: 0.733
# Epoch: 1/1..  Pérdida de entrenamiento: 0.880..  Pérdida de validación: 0.732..  Exactitud de validación: 0.737
# Epoch: 1/1..  Pérdida de entrenamiento: 0.858..  Pérdida de validación: 0.716..  Exactitud de validación: 0.741
# Epoch: 1/1..  Pérdida de entrenamiento: 0.851..  Pérdida de validación: 0.690..  Exactitud de validación: 0.753
# Epoch: 1/1..  Pérdida de entrenamiento: 0.795..  Pérdida de validación: 0.676..  Exactitud de validación: 0.753
# Epoch: 1/1..  Pérdida de entrenamiento: 0.785..  Pérdida de validación: 0.656..  Exactitud de validación: 0.758
# Epoch: 1/1..  Pérdida de entrenamiento: 0.759..  Pérdida de validación: 0.642..  Exactitud de validación: 0.762
# Epoch: 1/1..  Pérdida de entrenamiento: 0.753..  Pérdida de validación: 0.635..  Exactitud de validación: 0.771
# Epoch: 1/1..  Pérdida de entrenamiento: 0.742..  Pérdida de validación: 0.625..  Exactitud de validación: 0.767
# Epoch: 1/1..  Pérdida de entrenamiento: 0.716..  Pérdida de validación: 0.612..  Exactitud de validación: 0.778
# Epoch: 1/1..  Pérdida de entrenamiento: 0.732..  Pérdida de validación: 0.607..  Exactitud de validación: 0.773
# Epoch: 1/1..  Pérdida de entrenamiento: 0.633..  Pérdida de validación: 0.607..  Exactitud de validación: 0.773
# Epoch: 1/1..  Pérdida de entrenamiento: 0.619..  Pérdida de validación: 0.586..  Exactitud de validación: 0.780
# Epoch: 1/1..  Pérdida de entrenamiento: 0.660..  Pérdida de validación: 0.582..  Exactitud de validación: 0.788
# Epoch: 1/1..  Pérdida de entrenamiento: 0.640..  Pérdida de validación: 0.578..  Exactitud de validación: 0.785
# Epoch: 1/1..  Pérdida de entrenamiento: 0.630..  Pérdida de validación: 0.572..  Exactitud de validación: 0.791
# Epoch: 1/1..  Pérdida de entrenamiento: 0.625..  Pérdida de validación: 0.563..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.653..  Pérdida de validación: 0.564..  Exactitud de validación: 0.792
# Epoch: 1/1..  Pérdida de entrenamiento: 0.575..  Pérdida de validación: 0.561..  Exactitud de validación: 0.792
# Epoch: 1/1..  Pérdida de entrenamiento: 0.639..  Pérdida de validación: 0.554..  Exactitud de validación: 0.795
# Epoch: 1/1..  Pérdida de entrenamiento: 0.618..  Pérdida de validación: 0.549..  Exactitud de validación: 0.796
# Epoch: 1/1..  Pérdida de entrenamiento: 0.655..  Pérdida de validación: 0.537..  Exactitud de validación: 0.800
# Epoch: 1/1..  Pérdida de entrenamiento: 0.596..  Pérdida de validación: 0.548..  Exactitud de validación: 0.795
# Epoch: 1/1..  Pérdida de entrenamiento: 0.586..  Pérdida de validación: 0.547..  Exactitud de validación: 0.796
# Epoch: 1/1..  Pérdida de entrenamiento: 0.576..  Pérdida de validación: 0.529..  Exactitud de validación: 0.806
# Epoch: 1/1..  Pérdida de entrenamiento: 0.573..  Pérdida de validación: 0.525..  Exactitud de validación: 0.809
# Epoch: 1/1..  Pérdida de entrenamiento: 0.610..  Pérdida de validación: 0.534..  Exactitud de validación: 0.801
# Epoch: 1/1..  Pérdida de entrenamiento: 0.586..  Pérdida de validación: 0.527..  Exactitud de validación: 0.807
# Epoch: 1/1..  Pérdida de entrenamiento: 0.570..  Pérdida de validación: 0.523..  Exactitud de validación: 0.808
# Epoch: 1/1..  Pérdida de entrenamiento: 0.580..  Pérdida de validación: 0.513..  Exactitud de validación: 0.813
# Epoch: 1/1..  Pérdida de entrenamiento: 0.546..  Pérdida de validación: 0.513..  Exactitud de validación: 0.808
# Epoch: 1/1..  Pérdida de entrenamiento: 0.563..  Pérdida de validación: 0.512..  Exactitud de validación: 0.812
# Epoch: 1/1..  Pérdida de entrenamiento: 0.592..  Pérdida de validación: 0.511..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.543..  Pérdida de validación: 0.510..  Exactitud de validación: 0.810
# Epoch: 1/1..  Pérdida de entrenamiento: 0.530..  Pérdida de validación: 0.506..  Exactitud de validación: 0.813
# Epoch: 1/1..  Pérdida de entrenamiento: 0.524..  Pérdida de validación: 0.498..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.546..  Pérdida de validación: 0.498..  Exactitud de validación: 0.818
# Epoch: 1/1..  Pérdida de entrenamiento: 0.563..  Pérdida de validación: 0.499..  Exactitud de validación: 0.817
# Epoch: 1/1..  Pérdida de entrenamiento: 0.517..  Pérdida de validación: 0.497..  Exactitud de validación: 0.813
# Epoch: 1/1..  Pérdida de entrenamiento: 0.572..  Pérdida de validación: 0.494..  Exactitud de validación: 0.819
# Epoch: 1/1..  Pérdida de entrenamiento: 0.554..  Pérdida de validación: 0.489..  Exactitud de validación: 0.821
# Epoch: 1/1..  Pérdida de entrenamiento: 0.573..  Pérdida de validación: 0.534..  Exactitud de validación: 0.801
# Epoch: 1/1..  Pérdida de entrenamiento: 0.615..  Pérdida de validación: 0.510..  Exactitud de validación: 0.814
# Epoch: 1/1..  Pérdida de entrenamiento: 0.552..  Pérdida de validación: 0.500..  Exactitud de validación: 0.816
# Epoch: 1/1..  Pérdida de entrenamiento: 0.580..  Pérdida de validación: 0.503..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.546..  Pérdida de validación: 0.515..  Exactitud de validación: 0.802
# Epoch: 1/1..  Pérdida de entrenamiento: 0.568..  Pérdida de validación: 0.498..  Exactitud de validación: 0.819
# Epoch: 1/1..  Pérdida de entrenamiento: 0.537..  Pérdida de validación: 0.486..  Exactitud de validación: 0.823
# Epoch: 1/1..  Pérdida de entrenamiento: 0.562..  Pérdida de validación: 0.478..  Exactitud de validación: 0.826
# Epoch: 1/1..  Pérdida de entrenamiento: 0.555..  Pérdida de validación: 0.505..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.542..  Pérdida de validación: 0.483..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.562..  Pérdida de validación: 0.487..  Exactitud de validación: 0.821
# Epoch: 1/1..  Pérdida de entrenamiento: 0.526..  Pérdida de validación: 0.479..  Exactitud de validación: 0.826
# Epoch: 1/1..  Pérdida de entrenamiento: 0.543..  Pérdida de validación: 0.482..  Exactitud de validación: 0.823
# Epoch: 1/1..  Pérdida de entrenamiento: 0.500..  Pérdida de validación: 0.493..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.505..  Pérdida de validación: 0.469..  Exactitud de validación: 0.824
# Epoch: 1/1..  Pérdida de entrenamiento: 0.493..  Pérdida de validación: 0.468..  Exactitud de validación: 0.825
# Epoch: 1/1..  Pérdida de entrenamiento: 0.530..  Pérdida de validación: 0.496..  Exactitud de validación: 0.819
# Epoch: 1/1..  Pérdida de entrenamiento: 0.485..  Pérdida de validación: 0.473..  Exactitud de validación: 0.822
# Epoch: 1/1..  Pérdida de entrenamiento: 0.491..  Pérdida de validación: 0.458..  Exactitud de validación: 0.831
# Epoch: 1/1..  Pérdida de entrenamiento: 0.506..  Pérdida de validación: 0.518..  Exactitud de validación: 0.806
# Epoch: 1/1..  Pérdida de entrenamiento: 0.513..  Pérdida de validación: 0.489..  Exactitud de validación: 0.816
# Epoch: 1/1..  Pérdida de entrenamiento: 0.545..  Pérdida de validación: 0.456..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.490..  Pérdida de validación: 0.457..  Exactitud de validación: 0.834
# Epoch: 1/1..  Pérdida de entrenamiento: 0.508..  Pérdida de validación: 0.461..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.474..  Pérdida de validación: 0.454..  Exactitud de validación: 0.836
# Epoch: 1/1..  Pérdida de entrenamiento: 0.491..  Pérdida de validación: 0.455..  Exactitud de validación: 0.833
# Epoch: 1/1..  Pérdida de entrenamiento: 0.467..  Pérdida de validación: 0.461..  Exactitud de validación: 0.832
# Epoch: 1/1..  Pérdida de entrenamiento: 0.509..  Pérdida de validación: 0.472..  Exactitud de validación: 0.822
# Epoch: 1/1..  Pérdida de entrenamiento: 0.528..  Pérdida de validación: 0.446..  Exactitud de validación: 0.835
# Epoch: 1/1..  Pérdida de entrenamiento: 0.466..  Pérdida de validación: 0.454..  Exactitud de validación: 0.837
# Epoch: 1/1..  Pérdida de entrenamiento: 0.470..  Pérdida de validación: 0.448..  Exactitud de validación: 0.835
# Epoch: 1/1..  Pérdida de entrenamiento: 0.478..  Pérdida de validación: 0.466..  Exactitud de validación: 0.824
# Epoch: 1/1..  Pérdida de entrenamiento: 0.493..  Pérdida de validación: 0.440..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.425..  Pérdida de validación: 0.438..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.483..  Pérdida de validación: 0.452..  Exactitud de validación: 0.841
# Epoch: 1/1..  Pérdida de entrenamiento: 0.528..  Pérdida de validación: 0.443..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.483..  Pérdida de validación: 0.438..  Exactitud de validación: 0.841
# Epoch: 1/1..  Pérdida de entrenamiento: 0.492..  Pérdida de validación: 0.443..  Exactitud de validación: 0.837
# Epoch: 1/1..  Pérdida de entrenamiento: 0.459..  Pérdida de validación: 0.463..  Exactitud de validación: 0.833
# Epoch: 1/1..  Pérdida de entrenamiento: 0.486..  Pérdida de validación: 0.435..  Exactitud de validación: 0.841
# Epoch: 1/1..  Pérdida de entrenamiento: 0.422..  Pérdida de validación: 0.433..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.464..  Pérdida de validación: 0.440..  Exactitud de validación: 0.839
# Epoch: 1/1..  Pérdida de entrenamiento: 0.440..  Pérdida de validación: 0.433..  Exactitud de validación: 0.844
# Epoch: 1/1..  Pérdida de entrenamiento: 0.435..  Pérdida de validación: 0.435..  Exactitud de validación: 0.842
# Epoch: 1/1..  Pérdida de entrenamiento: 0.448..  Pérdida de validación: 0.437..  Exactitud de validación: 0.840
# Epoch: 1/1..  Pérdida de entrenamiento: 0.425..  Pérdida de validación: 0.436..  Exactitud de validación: 0.842
# Epoch: 1/1..  Pérdida de entrenamiento: 0.589..  Pérdida de validación: 0.497..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.550..  Pérdida de validación: 0.477..  Exactitud de validación: 0.826
# Epoch: 1/1..  Pérdida de entrenamiento: 0.516..  Pérdida de validación: 0.510..  Exactitud de validación: 0.818
# Epoch: 1/1..  Pérdida de entrenamiento: 0.595..  Pérdida de validación: 0.552..  Exactitud de validación: 0.802
# Epoch: 1/1..  Pérdida de entrenamiento: 0.569..  Pérdida de validación: 0.492..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.544..  Pérdida de validación: 0.505..  Exactitud de validación: 0.814
# Epoch: 1/1..  Pérdida de entrenamiento: 0.496..  Pérdida de validación: 0.473..  Exactitud de validación: 0.827
# Epoch: 1/1..  Pérdida de entrenamiento: 0.622..  Pérdida de validación: 0.495..  Exactitud de validación: 0.818
# Epoch: 1/1..  Pérdida de entrenamiento: 0.547..  Pérdida de validación: 0.479..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.555..  Pérdida de validación: 0.472..  Exactitud de validación: 0.831
# Epoch: 1/1..  Pérdida de entrenamiento: 0.541..  Pérdida de validación: 0.496..  Exactitud de validación: 0.817
# Epoch: 1/1..  Pérdida de entrenamiento: 0.594..  Pérdida de validación: 0.486..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.569..  Pérdida de validación: 0.493..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.549..  Pérdida de validación: 0.475..  Exactitud de validación: 0.825
# Epoch: 1/1..  Pérdida de entrenamiento: 0.557..  Pérdida de validación: 0.511..  Exactitud de validación: 0.814
# Epoch: 1/1..  Pérdida de entrenamiento: 0.594..  Pérdida de validación: 0.468..  Exactitud de validación: 0.826
# Epoch: 1/1..  Pérdida de entrenamiento: 0.533..  Pérdida de validación: 0.474..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.528..  Pérdida de validación: 0.474..  Exactitud de validación: 0.827
# Epoch: 1/1..  Pérdida de entrenamiento: 0.528..  Pérdida de validación: 0.486..  Exactitud de validación: 0.822
# Epoch: 1/1..  Pérdida de entrenamiento: 0.558..  Pérdida de validación: 0.471..  Exactitud de validación: 0.833
# Epoch: 1/1..  Pérdida de entrenamiento: 0.588..  Pérdida de validación: 0.463..  Exactitud de validación: 0.836
# Epoch: 1/1..  Pérdida de entrenamiento: 0.532..  Pérdida de validación: 0.492..  Exactitud de validación: 0.816
# Epoch: 1/1..  Pérdida de entrenamiento: 0.592..  Pérdida de validación: 0.477..  Exactitud de validación: 0.828
# Epoch: 1/1..  Pérdida de entrenamiento: 0.541..  Pérdida de validación: 0.458..  Exactitud de validación: 0.829
# Epoch: 1/1..  Pérdida de entrenamiento: 0.570..  Pérdida de validación: 0.463..  Exactitud de validación: 0.835
# Epoch: 1/1..  Pérdida de entrenamiento: 0.559..  Pérdida de validación: 0.451..  Exactitud de validación: 0.840
# Epoch: 1/1..  Pérdida de entrenamiento: 0.500..  Pérdida de validación: 0.477..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.546..  Pérdida de validación: 0.472..  Exactitud de validación: 0.831
# Epoch: 1/1..  Pérdida de entrenamiento: 0.522..  Pérdida de validación: 0.465..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.535..  Pérdida de validación: 0.449..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.567..  Pérdida de validación: 0.454..  Exactitud de validación: 0.837
# Epoch: 1/1..  Pérdida de entrenamiento: 0.523..  Pérdida de validación: 0.475..  Exactitud de validación: 0.826
# Epoch: 1/1..  Pérdida de entrenamiento: 0.584..  Pérdida de validación: 0.467..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.512..  Pérdida de validación: 0.466..  Exactitud de validación: 0.833
# Epoch: 1/1..  Pérdida de entrenamiento: 0.531..  Pérdida de validación: 0.457..  Exactitud de validación: 0.831
# Epoch: 1/1..  Pérdida de entrenamiento: 0.533..  Pérdida de validación: 0.492..  Exactitud de validación: 0.816
# Epoch: 1/1..  Pérdida de entrenamiento: 0.531..  Pérdida de validación: 0.448..  Exactitud de validación: 0.842
# Epoch: 1/1..  Pérdida de entrenamiento: 0.491..  Pérdida de validación: 0.467..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.492..  Pérdida de validación: 0.454..  Exactitud de validación: 0.834
# Epoch: 1/1..  Pérdida de entrenamiento: 0.559..  Pérdida de validación: 0.446..  Exactitud de validación: 0.835
# Epoch: 1/1..  Pérdida de entrenamiento: 0.516..  Pérdida de validación: 0.467..  Exactitud de validación: 0.828
# Epoch: 1/1..  Pérdida de entrenamiento: 0.528..  Pérdida de validación: 0.459..  Exactitud de validación: 0.831
# Epoch: 1/1..  Pérdida de entrenamiento: 0.540..  Pérdida de validación: 0.473..  Exactitud de validación: 0.825
# Epoch: 1/1..  Pérdida de entrenamiento: 0.487..  Pérdida de validación: 0.459..  Exactitud de validación: 0.828
# Epoch: 1/1..  Pérdida de entrenamiento: 0.589..  Pérdida de validación: 0.466..  Exactitud de validación: 0.830
# Epoch: 1/1..  Pérdida de entrenamiento: 0.513..  Pérdida de validación: 0.435..  Exactitud de validación: 0.838
# Epoch: 1/1..  Pérdida de entrenamiento: 0.748..  Pérdida de validación: 0.571..  Exactitud de validación: 0.800
# Epoch: 1/1..  Pérdida de entrenamiento: 0.788..  Pérdida de validación: 0.604..  Exactitud de validación: 0.794
# Epoch: 1/1..  Pérdida de entrenamiento: 0.840..  Pérdida de validación: 0.554..  Exactitud de validación: 0.809
# Epoch: 1/1..  Pérdida de entrenamiento: 0.728..  Pérdida de validación: 0.583..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.741..  Pérdida de validación: 0.624..  Exactitud de validación: 0.774
# Epoch: 1/1..  Pérdida de entrenamiento: 0.788..  Pérdida de validación: 0.566..  Exactitud de validación: 0.797
# Epoch: 1/1..  Pérdida de entrenamiento: 0.790..  Pérdida de validación: 0.557..  Exactitud de validación: 0.813
# Epoch: 1/1..  Pérdida de entrenamiento: 0.747..  Pérdida de validación: 0.565..  Exactitud de validación: 0.798
# Epoch: 1/1..  Pérdida de entrenamiento: 0.782..  Pérdida de validación: 0.587..  Exactitud de validación: 0.782
# Epoch: 1/1..  Pérdida de entrenamiento: 0.724..  Pérdida de validación: 0.580..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.770..  Pérdida de validación: 0.585..  Exactitud de validación: 0.786
# Epoch: 1/1..  Pérdida de entrenamiento: 0.858..  Pérdida de validación: 0.558..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.779..  Pérdida de validación: 0.598..  Exactitud de validación: 0.785
# Epoch: 1/1..  Pérdida de entrenamiento: 0.722..  Pérdida de validación: 0.531..  Exactitud de validación: 0.814
# Epoch: 1/1..  Pérdida de entrenamiento: 0.710..  Pérdida de validación: 0.539..  Exactitud de validación: 0.810
# Epoch: 1/1..  Pérdida de entrenamiento: 0.757..  Pérdida de validación: 0.548..  Exactitud de validación: 0.801
# Epoch: 1/1..  Pérdida de entrenamiento: 0.753..  Pérdida de validación: 0.565..  Exactitud de validación: 0.804
# Epoch: 1/1..  Pérdida de entrenamiento: 0.704..  Pérdida de validación: 0.597..  Exactitud de validación: 0.785
# Epoch: 1/1..  Pérdida de entrenamiento: 0.771..  Pérdida de validación: 0.588..  Exactitud de validación: 0.794
# Epoch: 1/1..  Pérdida de entrenamiento: 0.738..  Pérdida de validación: 0.586..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.693..  Pérdida de validación: 0.561..  Exactitud de validación: 0.808
# Epoch: 1/1..  Pérdida de entrenamiento: 0.697..  Pérdida de validación: 0.605..  Exactitud de validación: 0.776
# Epoch: 1/1..  Pérdida de entrenamiento: 0.678..  Pérdida de validación: 0.549..  Exactitud de validación: 0.800
# Epoch: 1/1..  Pérdida de entrenamiento: 0.769..  Pérdida de validación: 0.552..  Exactitud de validación: 0.813
# Epoch: 1/1..  Pérdida de entrenamiento: 0.750..  Pérdida de validación: 0.578..  Exactitud de validación: 0.770
# Epoch: 1/1..  Pérdida de entrenamiento: 0.734..  Pérdida de validación: 0.629..  Exactitud de validación: 0.785
# Epoch: 1/1..  Pérdida de entrenamiento: 0.694..  Pérdida de validación: 0.525..  Exactitud de validación: 0.811
# Epoch: 1/1..  Pérdida de entrenamiento: 0.774..  Pérdida de validación: 0.585..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.769..  Pérdida de validación: 0.574..  Exactitud de validación: 0.792
# Epoch: 1/1..  Pérdida de entrenamiento: 0.789..  Pérdida de validación: 0.567..  Exactitud de validación: 0.791
# Epoch: 1/1..  Pérdida de entrenamiento: 0.780..  Pérdida de validación: 0.532..  Exactitud de validación: 0.805
# Epoch: 1/1..  Pérdida de entrenamiento: 0.796..  Pérdida de validación: 0.577..  Exactitud de validación: 0.796
# Epoch: 1/1..  Pérdida de entrenamiento: 0.760..  Pérdida de validación: 0.552..  Exactitud de validación: 0.807
# Epoch: 1/1..  Pérdida de entrenamiento: 0.709..  Pérdida de validación: 0.566..  Exactitud de validación: 0.808
# Epoch: 1/1..  Pérdida de entrenamiento: 0.776..  Pérdida de validación: 0.567..  Exactitud de validación: 0.799
# Epoch: 1/1..  Pérdida de entrenamiento: 0.738..  Pérdida de validación: 0.539..  Exactitud de validación: 0.815
# Epoch: 1/1..  Pérdida de entrenamiento: 0.744..  Pérdida de validación: 0.541..  Exactitud de validación: 0.811
# Epoch: 1/1..  Pérdida de entrenamiento: 0.648..  Pérdida de validación: 0.566..  Exactitud de validación: 0.800
# Epoch: 1/1..  Pérdida de entrenamiento: 0.704..  Pérdida de validación: 0.555..  Exactitud de validación: 0.809
# Epoch: 1/1..  Pérdida de entrenamiento: 0.719..  Pérdida de validación: 0.557..  Exactitud de validación: 0.806
# Epoch: 1/1..  Pérdida de entrenamiento: 0.763..  Pérdida de validación: 0.574..  Exactitud de validación: 0.802
# Epoch: 1/1..  Pérdida de entrenamiento: 0.762..  Pérdida de validación: 0.598..  Exactitud de validación: 0.790
# Epoch: 1/1..  Pérdida de entrenamiento: 0.706..  Pérdida de validación: 0.555..  Exactitud de validación: 0.808
# Epoch: 1/1..  Pérdida de entrenamiento: 0.719..  Pérdida de validación: 0.525..  Exactitud de validación: 0.820
# Epoch: 1/1..  Pérdida de entrenamiento: 0.748..  Pérdida de validación: 0.580..  Exactitud de validación: 0.809
# Epoch: 1/1..  Pérdida de entrenamiento: 0.702..  Pérdida de validación: 0.572..  Exactitud de validación: 0.799
# Epoch: 1/1..  Pérdida de entrenamiento: 1.677..  Pérdida de validación: 0.934..  Exactitud de validación: 0.715
# Epoch: 1/1..  Pérdida de entrenamiento: 1.690..  Pérdida de validación: 0.964..  Exactitud de validación: 0.672
# Epoch: 1/1..  Pérdida de entrenamiento: 1.453..  Pérdida de validación: 0.874..  Exactitud de validación: 0.757
# Epoch: 1/1..  Pérdida de entrenamiento: 1.599..  Pérdida de validación: 0.963..  Exactitud de validación: 0.614
# Epoch: 1/1..  Pérdida de entrenamiento: 1.591..  Pérdida de validación: 0.989..  Exactitud de validación: 0.674
# Epoch: 1/1..  Pérdida de entrenamiento: 1.883..  Pérdida de validación: 0.865..  Exactitud de validación: 0.704
# Epoch: 1/1..  Pérdida de entrenamiento: 1.601..  Pérdida de validación: 1.170..  Exactitud de validación: 0.616
# Epoch: 1/1..  Pérdida de entrenamiento: 1.656..  Pérdida de validación: 1.032..  Exactitud de validación: 0.650
# Epoch: 1/1..  Pérdida de entrenamiento: 1.678..  Pérdida de validación: 1.200..  Exactitud de validación: 0.570
# Epoch: 1/1..  Pérdida de entrenamiento: 2.006..  Pérdida de validación: 1.155..  Exactitud de validación: 0.598
# Epoch: 1/1..  Pérdida de entrenamiento: 1.692..  Pérdida de validación: 1.056..  Exactitud de validación: 0.631
# Epoch: 1/1..  Pérdida de entrenamiento: 1.941..  Pérdida de validación: 1.207..  Exactitud de validación: 0.613
# Epoch: 1/1..  Pérdida de entrenamiento: 1.841..  Pérdida de validación: 1.148..  Exactitud de validación: 0.629
# Epoch: 1/1..  Pérdida de entrenamiento: 1.690..  Pérdida de validación: 1.106..  Exactitud de validación: 0.604
# Epoch: 1/1..  Pérdida de entrenamiento: 1.902..  Pérdida de validación: 1.408..  Exactitud de validación: 0.545
# Epoch: 1/1..  Pérdida de entrenamiento: 1.837..  Pérdida de validación: 1.171..  Exactitud de validación: 0.610
# Epoch: 1/1..  Pérdida de entrenamiento: 2.039..  Pérdida de validación: 1.294..  Exactitud de validación: 0.533
# Epoch: 1/1..  Pérdida de entrenamiento: 1.909..  Pérdida de validación: 1.291..  Exactitud de validación: 0.553
# Epoch: 1/1..  Pérdida de entrenamiento: 1.626..  Pérdida de validación: 1.092..  Exactitud de validación: 0.635
# Epoch: 1/1..  Pérdida de entrenamiento: 1.754..  Pérdida de validación: 1.052..  Exactitud de validación: 0.618
# Epoch: 1/1..  Pérdida de entrenamiento: 1.565..  Pérdida de validación: 0.983..  Exactitud de validación: 0.638
# Epoch: 1/1..  Pérdida de entrenamiento: 1.448..  Pérdida de validación: 1.036..  Exactitud de validación: 0.610
# Epoch: 1/1..  Pérdida de entrenamiento: 1.441..  Pérdida de validación: 0.922..  Exactitud de validación: 0.685
# Epoch: 1/1..  Pérdida de entrenamiento: 1.426..  Pérdida de validación: 0.978..  Exactitud de validación: 0.640
# Epoch: 1/1..  Pérdida de entrenamiento: 1.485..  Pérdida de validación: 1.019..  Exactitud de validación: 0.634
# Epoch: 1/1..  Pérdida de entrenamiento: 1.382..  Pérdida de validación: 0.941..  Exactitud de validación: 0.684
# Epoch: 1/1..  Pérdida de entrenamiento: 1.531..  Pérdida de validación: 0.927..  Exactitud de validación: 0.645
# Epoch: 1/1..  Pérdida de entrenamiento: 1.571..  Pérdida de validación: 1.062..  Exactitud de validación: 0.615
# Epoch: 1/1..  Pérdida de entrenamiento: 1.543..  Pérdida de validación: 0.967..  Exactitud de validación: 0.626
# Epoch: 1/1..  Pérdida de entrenamiento: 1.566..  Pérdida de validación: 1.002..  Exactitud de validación: 0.593
# Epoch: 1/1..  Pérdida de entrenamiento: 1.473..  Pérdida de validación: 0.991..  Exactitud de validación: 0.677
# Epoch: 1/1..  Pérdida de entrenamiento: 1.372..  Pérdida de validación: 0.892..  Exactitud de validación: 0.660
# Epoch: 1/1..  Pérdida de entrenamiento: 1.515..  Pérdida de validación: 0.979..  Exactitud de validación: 0.665
# Epoch: 1/1..  Pérdida de entrenamiento: 1.747..  Pérdida de validación: 1.092..  Exactitud de validación: 0.663
# Epoch: 1/1..  Pérdida de entrenamiento: 1.446..  Pérdida de validación: 1.024..  Exactitud de validación: 0.699
# Epoch: 1/1..  Pérdida de entrenamiento: 1.450..  Pérdida de validación: 1.143..  Exactitud de validación: 0.695
# Epoch: 1/1..  Pérdida de entrenamiento: 1.395..  Pérdida de validación: 0.959..  Exactitud de validación: 0.696
# Epoch: 1/1..  Pérdida de entrenamiento: 1.397..  Pérdida de validación: 1.029..  Exactitud de validación: 0.664
# Epoch: 1/1..  Pérdida de entrenamiento: 1.388..  Pérdida de validación: 0.898..  Exactitud de validación: 0.687
# Epoch: 1/1..  Pérdida de entrenamiento: 1.340..  Pérdida de validación: 0.878..  Exactitud de validación: 0.672
# Epoch: 1/1..  Pérdida de entrenamiento: 1.579..  Pérdida de validación: 1.008..  Exactitud de validación: 0.656
# Epoch: 1/1..  Pérdida de entrenamiento: 1.408..  Pérdida de validación: 0.936..  Exactitud de validación: 0.681
# Epoch: 1/1..  Pérdida de entrenamiento: 1.310..  Pérdida de validación: 0.854..  Exactitud de validación: 0.716
# Epoch: 1/1..  Pérdida de entrenamiento: 1.490..  Pérdida de validación: 0.950..  Exactitud de validación: 0.648
# Epoch: 1/1..  Pérdida de entrenamiento: 1.449..  Pérdida de validación: 0.913..  Exactitud de validación: 0.674
# Epoch: 1/1..  Pérdida de entrenamiento: 1.523..  Pérdida de validación: 0.917..  Exactitud de validación: 0.646
# Epoch: 1/1..  Pérdida de entrenamiento: 1.413..  Pérdida de validación: 0.918..  Exactitud de validación: 0.703
# Epoch: 1/1..  Pérdida de entrenamiento: 1.243..  Pérdida de validación: 0.900..  Exactitud de validación: 0.707
# Epoch: 1/1..  Pérdida de entrenamiento: 1.308..  Pérdida de validación: 0.897..  Exactitud de validación: 0.708
# Epoch: 1/1..  Pérdida de entrenamiento: 1.302..  Pérdida de validación: 0.885..  Exactitud de validación: 0.709
# Epoch: 1/1..  Pérdida de entrenamiento: 1.336..  Pérdida de validación: 0.884..  Exactitud de validación: 0.710
# Epoch: 1/1..  Pérdida de entrenamiento: 1.246..  Pérdida de validación: 0.881..  Exactitud de validación: 0.712
# Epoch: 1/1..  Pérdida de entrenamiento: 1.255..  Pérdida de validación: 0.879..  Exactitud de validación: 0.713
# Epoch: 1/1..  Pérdida de entrenamiento: 1.209..  Pérdida de validación: 0.871..  Exactitud de validación: 0.713
# Epoch: 1/1..  Pérdida de entrenamiento: 1.233..  Pérdida de validación: 0.871..  Exactitud de validación: 0.713
# Epoch: 1/1..  Pérdida de entrenamiento: 1.170..  Pérdida de validación: 0.865..  Exactitud de validación: 0.718
# Epoch: 1/1..  Pérdida de entrenamiento: 1.346..  Pérdida de validación: 0.864..  Exactitud de validación: 0.721
# Epoch: 1/1..  Pérdida de entrenamiento: 1.264..  Pérdida de validación: 0.860..  Exactitud de validación: 0.720
# Epoch: 1/1..  Pérdida de entrenamiento: 1.269..  Pérdida de validación: 0.862..  Exactitud de validación: 0.717
# Epoch: 1/1..  Pérdida de entrenamiento: 1.221..  Pérdida de validación: 0.858..  Exactitud de validación: 0.713
# Epoch: 1/1..  Pérdida de entrenamiento: 1.268..  Pérdida de validación: 0.850..  Exactitud de validación: 0.720
# Epoch: 1/1..  Pérdida de entrenamiento: 1.156..  Pérdida de validación: 0.846..  Exactitud de validación: 0.722
# Epoch: 1/1..  Pérdida de entrenamiento: 1.173..  Pérdida de validación: 0.841..  Exactitud de validación: 0.725
# Epoch: 1/1..  Pérdida de entrenamiento: 1.228..  Pérdida de validación: 0.840..  Exactitud de validación: 0.726
# Epoch: 1/1..  Pérdida de entrenamiento: 1.289..  Pérdida de validación: 0.839..  Exactitud de validación: 0.726
# Epoch: 1/1..  Pérdida de entrenamiento: 1.178..  Pérdida de validación: 0.838..  Exactitud de validación: 0.724
# Epoch: 1/1..  Pérdida de entrenamiento: 1.220..  Pérdida de validación: 0.837..  Exactitud de validación: 0.706
# Epoch: 1/1..  Pérdida de entrenamiento: 1.127..  Pérdida de validación: 0.831..  Exactitud de validación: 0.727
# Epoch: 1/1..  Pérdida de entrenamiento: 1.169..  Pérdida de validación: 0.829..  Exactitud de validación: 0.725
# Epoch: 1/1..  Pérdida de entrenamiento: 1.150..  Pérdida de validación: 0.827..  Exactitud de validación: 0.727
# Epoch: 1/1..  Pérdida de entrenamiento: 1.201..  Pérdida de validación: 0.825..  Exactitud de validación: 0.728
# Epoch: 1/1..  Pérdida de entrenamiento: 1.248..  Pérdida de validación: 0.824..  Exactitud de validación: 0.728
# Epoch: 1/1..  Pérdida de entrenamiento: 1.308..  Pérdida de validación: 0.831..  Exactitud de validación: 0.722
# Epoch: 1/1..  Pérdida de entrenamiento: 1.204..  Pérdida de validación: 0.830..  Exactitud de validación: 0.726
# Epoch: 1/1..  Pérdida de entrenamiento: 1.198..  Pérdida de validación: 0.825..  Exactitud de validación: 0.728
# Epoch: 1/1..  Pérdida de entrenamiento: 1.245..  Pérdida de validación: 0.821..  Exactitud de validación: 0.724
# Epoch: 1/1..  Pérdida de entrenamiento: 1.187..  Pérdida de validación: 0.819..  Exactitud de validación: 0.722
# Epoch: 1/1..  Pérdida de entrenamiento: 1.241..  Pérdida de validación: 0.813..  Exactitud de validación: 0.729
# Epoch: 1/1..  Pérdida de entrenamiento: 1.099..  Pérdida de validación: 0.809..  Exactitud de validación: 0.729
# Epoch: 1/1..  Pérdida de entrenamiento: 1.173..  Pérdida de validación: 0.810..  Exactitud de validación: 0.730
# Epoch: 1/1..  Pérdida de entrenamiento: 1.188..  Pérdida de validación: 0.809..  Exactitud de validación: 0.708
# Epoch: 1/1..  Pérdida de entrenamiento: 1.170..  Pérdida de validación: 0.808..  Exactitud de validación: 0.718
# Epoch: 1/1..  Pérdida de entrenamiento: 1.140..  Pérdida de validación: 0.803..  Exactitud de validación: 0.724
# Epoch: 1/1..  Pérdida de entrenamiento: 1.091..  Pérdida de validación: 0.803..  Exactitud de validación: 0.730
# Epoch: 1/1..  Pérdida de entrenamiento: 1.127..  Pérdida de validación: 0.803..  Exactitud de validación: 0.732
# Epoch: 1/1..  Pérdida de entrenamiento: 1.171..  Pérdida de validación: 0.808..  Exactitud de validación: 0.731
# Epoch: 1/1..  Pérdida de entrenamiento: 1.104..  Pérdida de validación: 0.805..  Exactitud de validación: 0.728
# Epoch: 1/1..  Pérdida de entrenamiento: 1.128..  Pérdida de validación: 0.800..  Exactitud de validación: 0.729
# Epoch: 1/1..  Pérdida de entrenamiento: 1.166..  Pérdida de validación: 0.800..  Exactitud de validación: 0.731
# Epoch: 1/1..  Pérdida de entrenamiento: 1.129..  Pérdida de validación: 0.799..  Exactitud de validación: 0.732
# Epoch: 1/1..  Pérdida de entrenamiento: 1.152..  Pérdida de validación: 0.796..  Exactitud de validación: 0.735
# Epoch: 1/1..  Pérdida de entrenamiento: 1.172..  Pérdida de validación: 0.799..  Exactitud de validación: 0.731
# Epoch: 1/2..  Pérdida de entrenamiento: 1.140..  Pérdida de validación: 0.789..  Exactitud de validación: 0.727
# Epoch: 1/2..  Pérdida de entrenamiento: 1.139..  Pérdida de validación: 0.791..  Exactitud de validación: 0.737
# Epoch: 1/2..  Pérdida de entrenamiento: 1.115..  Pérdida de validación: 0.788..  Exactitud de validación: 0.728
# Epoch: 1/2..  Pérdida de entrenamiento: 1.110..  Pérdida de validación: 0.790..  Exactitud de validación: 0.727
# Epoch: 1/2..  Pérdida de entrenamiento: 1.144..  Pérdida de validación: 0.788..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.123..  Pérdida de validación: 0.791..  Exactitud de validación: 0.732
# Epoch: 1/2..  Pérdida de entrenamiento: 1.106..  Pérdida de validación: 0.791..  Exactitud de validación: 0.735
# Epoch: 1/2..  Pérdida de entrenamiento: 1.068..  Pérdida de validación: 0.786..  Exactitud de validación: 0.739
# Epoch: 1/2..  Pérdida de entrenamiento: 1.112..  Pérdida de validación: 0.787..  Exactitud de validación: 0.733
# Epoch: 1/2..  Pérdida de entrenamiento: 1.092..  Pérdida de validación: 0.784..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.118..  Pérdida de validación: 0.789..  Exactitud de validación: 0.737
# Epoch: 1/2..  Pérdida de entrenamiento: 1.020..  Pérdida de validación: 0.781..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.139..  Pérdida de validación: 0.784..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.024..  Pérdida de validación: 0.785..  Exactitud de validación: 0.734
# Epoch: 1/2..  Pérdida de entrenamiento: 1.252..  Pérdida de validación: 0.785..  Exactitud de validación: 0.735
# Epoch: 1/2..  Pérdida de entrenamiento: 1.077..  Pérdida de validación: 0.787..  Exactitud de validación: 0.738
# Epoch: 1/2..  Pérdida de entrenamiento: 1.064..  Pérdida de validación: 0.785..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.067..  Pérdida de validación: 0.774..  Exactitud de validación: 0.736
# Epoch: 1/2..  Pérdida de entrenamiento: 1.044..  Pérdida de validación: 0.773..  Exactitud de validación: 0.743
# Epoch: 1/2..  Pérdida de entrenamiento: 1.114..  Pérdida de validación: 0.774..  Exactitud de validación: 0.743
# Epoch: 1/2..  Pérdida de entrenamiento: 1.061..  Pérdida de validación: 0.766..  Exactitud de validación: 0.742
# Epoch: 1/2..  Pérdida de entrenamiento: 1.084..  Pérdida de validación: 0.766..  Exactitud de validación: 0.744
# Epoch: 1/2..  Pérdida de entrenamiento: 1.096..  Pérdida de validación: 0.765..  Exactitud de validación: 0.744
# Epoch: 1/2..  Pérdida de entrenamiento: 1.113..  Pérdida de validación: 0.763..  Exactitud de validación: 0.745
# Epoch: 1/2..  Pérdida de entrenamiento: 1.097..  Pérdida de validación: 0.767..  Exactitud de validación: 0.741
# Epoch: 1/2..  Pérdida de entrenamiento: 1.025..  Pérdida de validación: 0.766..  Exactitud de validación: 0.745
# Epoch: 1/2..  Pérdida de entrenamiento: 0.992..  Pérdida de validación: 0.761..  Exactitud de validación: 0.731
# Epoch: 1/2..  Pérdida de entrenamiento: 1.085..  Pérdida de validación: 0.763..  Exactitud de validación: 0.729
# Epoch: 1/2..  Pérdida de entrenamiento: 1.081..  Pérdida de validación: 0.764..  Exactitud de validación: 0.741
# Epoch: 1/2..  Pérdida de entrenamiento: 1.033..  Pérdida de validación: 0.762..  Exactitud de validación: 0.742
# Epoch: 1/2..  Pérdida de entrenamiento: 1.002..  Pérdida de validación: 0.759..  Exactitud de validación: 0.746
# Epoch: 1/2..  Pérdida de entrenamiento: 1.049..  Pérdida de validación: 0.762..  Exactitud de validación: 0.741
# Epoch: 1/2..  Pérdida de entrenamiento: 1.020..  Pérdida de validación: 0.763..  Exactitud de validación: 0.732
# Epoch: 1/2..  Pérdida de entrenamiento: 1.044..  Pérdida de validación: 0.762..  Exactitud de validación: 0.717
# Epoch: 1/2..  Pérdida de entrenamiento: 1.011..  Pérdida de validación: 0.760..  Exactitud de validación: 0.747
# Epoch: 1/2..  Pérdida de entrenamiento: 1.010..  Pérdida de validación: 0.762..  Exactitud de validación: 0.730
# Epoch: 1/2..  Pérdida de entrenamiento: 1.009..  Pérdida de validación: 0.759..  Exactitud de validación: 0.733
# Epoch: 1/2..  Pérdida de entrenamiento: 1.001..  Pérdida de validación: 0.752..  Exactitud de validación: 0.744
# Epoch: 1/2..  Pérdida de entrenamiento: 1.036..  Pérdida de validación: 0.752..  Exactitud de validación: 0.739
# Epoch: 1/2..  Pérdida de entrenamiento: 0.978..  Pérdida de validación: 0.754..  Exactitud de validación: 0.737
# Epoch: 1/2..  Pérdida de entrenamiento: 1.025..  Pérdida de validación: 0.759..  Exactitud de validación: 0.740
# Epoch: 1/2..  Pérdida de entrenamiento: 1.022..  Pérdida de validación: 0.752..  Exactitud de validación: 0.744
# Epoch: 1/2..  Pérdida de entrenamiento: 0.990..  Pérdida de validación: 0.748..  Exactitud de validación: 0.746
# Epoch: 1/2..  Pérdida de entrenamiento: 0.963..  Pérdida de validación: 0.747..  Exactitud de validación: 0.747
# Epoch: 1/2..  Pérdida de entrenamiento: 1.025..  Pérdida de validación: 0.749..  Exactitud de validación: 0.745
# Epoch: 1/2..  Pérdida de entrenamiento: 0.978..  Pérdida de validación: 0.748..  Exactitud de validación: 0.740
# Epoch: 2/2..  Pérdida de entrenamiento: 0.929..  Pérdida de validación: 0.751..  Exactitud de validación: 0.743
# Epoch: 2/2..  Pérdida de entrenamiento: 0.985..  Pérdida de validación: 0.750..  Exactitud de validación: 0.742
# Epoch: 2/2..  Pérdida de entrenamiento: 0.945..  Pérdida de validación: 0.746..  Exactitud de validación: 0.733
# Epoch: 2/2..  Pérdida de entrenamiento: 0.989..  Pérdida de validación: 0.745..  Exactitud de validación: 0.737
# Epoch: 2/2..  Pérdida de entrenamiento: 0.987..  Pérdida de validación: 0.746..  Exactitud de validación: 0.742
# Epoch: 2/2..  Pérdida de entrenamiento: 1.004..  Pérdida de validación: 0.748..  Exactitud de validación: 0.746
# Epoch: 2/2..  Pérdida de entrenamiento: 0.980..  Pérdida de validación: 0.749..  Exactitud de validación: 0.741
# Epoch: 2/2..  Pérdida de entrenamiento: 0.969..  Pérdida de validación: 0.744..  Exactitud de validación: 0.739
# Epoch: 2/2..  Pérdida de entrenamiento: 0.966..  Pérdida de validación: 0.741..  Exactitud de validación: 0.738
# Epoch: 2/2..  Pérdida de entrenamiento: 1.099..  Pérdida de validación: 0.751..  Exactitud de validación: 0.747
# Epoch: 2/2..  Pérdida de entrenamiento: 1.028..  Pérdida de validación: 0.746..  Exactitud de validación: 0.749
# Epoch: 2/2..  Pérdida de entrenamiento: 0.938..  Pérdida de validación: 0.737..  Exactitud de validación: 0.733
# Epoch: 2/2..  Pérdida de entrenamiento: 1.124..  Pérdida de validación: 0.739..  Exactitud de validación: 0.732
# Epoch: 2/2..  Pérdida de entrenamiento: 0.906..  Pérdida de validación: 0.739..  Exactitud de validación: 0.743
# Epoch: 2/2..  Pérdida de entrenamiento: 0.981..  Pérdida de validación: 0.734..  Exactitud de validación: 0.740
# Epoch: 2/2..  Pérdida de entrenamiento: 0.922..  Pérdida de validación: 0.736..  Exactitud de validación: 0.741
# Epoch: 2/2..  Pérdida de entrenamiento: 0.982..  Pérdida de validación: 0.734..  Exactitud de validación: 0.744
# Epoch: 2/2..  Pérdida de entrenamiento: 0.939..  Pérdida de validación: 0.735..  Exactitud de validación: 0.743
# Epoch: 2/2..  Pérdida de entrenamiento: 1.001..  Pérdida de validación: 0.737..  Exactitud de validación: 0.735
# Epoch: 2/2..  Pérdida de entrenamiento: 1.000..  Pérdida de validación: 0.739..  Exactitud de validación: 0.740
# Epoch: 2/2..  Pérdida de entrenamiento: 0.954..  Pérdida de validación: 0.735..  Exactitud de validación: 0.733
# Epoch: 2/2..  Pérdida de entrenamiento: 0.938..  Pérdida de validación: 0.734..  Exactitud de validación: 0.738
# Epoch: 2/2..  Pérdida de entrenamiento: 0.990..  Pérdida de validación: 0.734..  Exactitud de validación: 0.745
# Epoch: 2/2..  Pérdida de entrenamiento: 0.947..  Pérdida de validación: 0.734..  Exactitud de validación: 0.743
# Epoch: 2/2..  Pérdida de entrenamiento: 0.961..  Pérdida de validación: 0.731..  Exactitud de validación: 0.747
# Epoch: 2/2..  Pérdida de entrenamiento: 0.935..  Pérdida de validación: 0.731..  Exactitud de validación: 0.716
# Epoch: 2/2..  Pérdida de entrenamiento: 0.939..  Pérdida de validación: 0.727..  Exactitud de validación: 0.732
# Epoch: 2/2..  Pérdida de entrenamiento: 0.927..  Pérdida de validación: 0.727..  Exactitud de validación: 0.743
# Epoch: 2/2..  Pérdida de entrenamiento: 0.924..  Pérdida de validación: 0.721..  Exactitud de validación: 0.747
# Epoch: 2/2..  Pérdida de entrenamiento: 0.991..  Pérdida de validación: 0.721..  Exactitud de validación: 0.740
# Epoch: 2/2..  Pérdida de entrenamiento: 0.946..  Pérdida de validación: 0.728..  Exactitud de validación: 0.735
# Epoch: 2/2..  Pérdida de entrenamiento: 0.929..  Pérdida de validación: 0.730..  Exactitud de validación: 0.747
# Epoch: 2/2..  Pérdida de entrenamiento: 0.955..  Pérdida de validación: 0.727..  Exactitud de validación: 0.750
# Epoch: 2/2..  Pérdida de entrenamiento: 0.958..  Pérdida de validación: 0.727..  Exactitud de validación: 0.749
# Epoch: 2/2..  Pérdida de entrenamiento: 0.975..  Pérdida de validación: 0.725..  Exactitud de validación: 0.749
# Epoch: 2/2..  Pérdida de entrenamiento: 0.898..  Pérdida de validación: 0.733..  Exactitud de validación: 0.744
# Epoch: 2/2..  Pérdida de entrenamiento: 0.939..  Pérdida de validación: 0.726..  Exactitud de validación: 0.745
# Epoch: 2/2..  Pérdida de entrenamiento: 0.989..  Pérdida de validación: 0.724..  Exactitud de validación: 0.748
# Epoch: 2/2..  Pérdida de entrenamiento: 0.913..  Pérdida de validación: 0.723..  Exactitud de validación: 0.751
# Epoch: 2/2..  Pérdida de entrenamiento: 0.947..  Pérdida de validación: 0.717..  Exactitud de validación: 0.746
# Epoch: 2/2..  Pérdida de entrenamiento: 0.908..  Pérdida de validación: 0.709..  Exactitud de validación: 0.751
# Epoch: 2/2..  Pérdida de entrenamiento: 0.871..  Pérdida de validación: 0.704..  Exactitud de validación: 0.750
# Epoch: 2/2..  Pérdida de entrenamiento: 0.974..  Pérdida de validación: 0.704..  Exactitud de validación: 0.750
# Epoch: 2/2..  Pérdida de entrenamiento: 0.890..  Pérdida de validación: 0.703..  Exactitud de validación: 0.749
# Epoch: 2/2..  Pérdida de entrenamiento: 0.948..  Pérdida de validación: 0.701..  Exactitud de validación: 0.746
# Epoch: 2/2..  Pérdida de entrenamiento: 0.989..  Pérdida de validación: 0.706..  Exactitud de validación: 0.744
# Epoch: 2/2..  Pérdida de entrenamiento: 0.906..  Pérdida de validación: 0.703..  Exactitud de validación: 0.748
# Epoch: 1/3..  Pérdida de entrenamiento: 0.895..  Pérdida de validación: 0.692..  Exactitud de validación: 0.749
# Epoch: 1/3..  Pérdida de entrenamiento: 0.866..  Pérdida de validación: 0.689..  Exactitud de validación: 0.754
# Epoch: 1/3..  Pérdida de entrenamiento: 0.892..  Pérdida de validación: 0.687..  Exactitud de validación: 0.753
# Epoch: 1/3..  Pérdida de entrenamiento: 0.910..  Pérdida de validación: 0.689..  Exactitud de validación: 0.753
# Epoch: 1/3..  Pérdida de entrenamiento: 0.955..  Pérdida de validación: 0.690..  Exactitud de validación: 0.755
# Epoch: 1/3..  Pérdida de entrenamiento: 0.916..  Pérdida de validación: 0.690..  Exactitud de validación: 0.757
# Epoch: 1/3..  Pérdida de entrenamiento: 0.895..  Pérdida de validación: 0.689..  Exactitud de validación: 0.752
# Epoch: 1/3..  Pérdida de entrenamiento: 1.017..  Pérdida de validación: 0.693..  Exactitud de validación: 0.754
# Epoch: 1/3..  Pérdida de entrenamiento: 0.950..  Pérdida de validación: 0.691..  Exactitud de validación: 0.752
# Epoch: 1/3..  Pérdida de entrenamiento: 0.888..  Pérdida de validación: 0.689..  Exactitud de validación: 0.751
# Epoch: 1/3..  Pérdida de entrenamiento: 0.952..  Pérdida de validación: 0.694..  Exactitud de validación: 0.752
# Epoch: 1/3..  Pérdida de entrenamiento: 0.897..  Pérdida de validación: 0.693..  Exactitud de validación: 0.756
# Epoch: 1/3..  Pérdida de entrenamiento: 0.831..  Pérdida de validación: 0.687..  Exactitud de validación: 0.762
# Epoch: 1/3..  Pérdida de entrenamiento: 0.981..  Pérdida de validación: 0.687..  Exactitud de validación: 0.755
# Epoch: 1/3..  Pérdida de entrenamiento: 0.862..  Pérdida de validación: 0.688..  Exactitud de validación: 0.756
# Epoch: 1/3..  Pérdida de entrenamiento: 0.932..  Pérdida de validación: 0.689..  Exactitud de validación: 0.757
# Epoch: 1/3..  Pérdida de entrenamiento: 0.887..  Pérdida de validación: 0.690..  Exactitud de validación: 0.758
# Epoch: 1/3..  Pérdida de entrenamiento: 0.836..  Pérdida de validación: 0.681..  Exactitud de validación: 0.762
# Epoch: 1/3..  Pérdida de entrenamiento: 0.910..  Pérdida de validación: 0.682..  Exactitud de validación: 0.761
# Epoch: 1/3..  Pérdida de entrenamiento: 0.873..  Pérdida de validación: 0.681..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.959..  Pérdida de validación: 0.681..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.936..  Pérdida de validación: 0.688..  Exactitud de validación: 0.756
# Epoch: 1/3..  Pérdida de entrenamiento: 0.854..  Pérdida de validación: 0.682..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.920..  Pérdida de validación: 0.683..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.921..  Pérdida de validación: 0.683..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.863..  Pérdida de validación: 0.675..  Exactitud de validación: 0.761
# Epoch: 1/3..  Pérdida de entrenamiento: 0.945..  Pérdida de validación: 0.677..  Exactitud de validación: 0.761
# Epoch: 1/3..  Pérdida de entrenamiento: 0.965..  Pérdida de validación: 0.682..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.829..  Pérdida de validación: 0.678..  Exactitud de validación: 0.761
# Epoch: 1/3..  Pérdida de entrenamiento: 0.885..  Pérdida de validación: 0.680..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.894..  Pérdida de validación: 0.682..  Exactitud de validación: 0.758
# Epoch: 1/3..  Pérdida de entrenamiento: 0.902..  Pérdida de validación: 0.681..  Exactitud de validación: 0.757
# Epoch: 1/3..  Pérdida de entrenamiento: 0.931..  Pérdida de validación: 0.678..  Exactitud de validación: 0.760
# Epoch: 1/3..  Pérdida de entrenamiento: 0.855..  Pérdida de validación: 0.678..  Exactitud de validación: 0.762
# Epoch: 1/3..  Pérdida de entrenamiento: 0.856..  Pérdida de validación: 0.676..  Exactitud de validación: 0.760
# Epoch: 1/3..  Pérdida de entrenamiento: 0.890..  Pérdida de validación: 0.677..  Exactitud de validación: 0.757
# Epoch: 1/3..  Pérdida de entrenamiento: 0.919..  Pérdida de validación: 0.673..  Exactitud de validación: 0.754
# Epoch: 1/3..  Pérdida de entrenamiento: 0.883..  Pérdida de validación: 0.673..  Exactitud de validación: 0.758
# Epoch: 1/3..  Pérdida de entrenamiento: 0.821..  Pérdida de validación: 0.672..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.839..  Pérdida de validación: 0.673..  Exactitud de validación: 0.760
# Epoch: 1/3..  Pérdida de entrenamiento: 0.902..  Pérdida de validación: 0.675..  Exactitud de validación: 0.760
# Epoch: 1/3..  Pérdida de entrenamiento: 0.844..  Pérdida de validación: 0.674..  Exactitud de validación: 0.759
# Epoch: 1/3..  Pérdida de entrenamiento: 0.891..  Pérdida de validación: 0.674..  Exactitud de validación: 0.763
# Epoch: 1/3..  Pérdida de entrenamiento: 0.846..  Pérdida de validación: 0.674..  Exactitud de validación: 0.763
# Epoch: 1/3..  Pérdida de entrenamiento: 0.848..  Pérdida de validación: 0.676..  Exactitud de validación: 0.762
# Epoch: 1/3..  Pérdida de entrenamiento: 0.877..  Pérdida de validación: 0.684..  Exactitud de validación: 0.760
# Epoch: 2/3..  Pérdida de entrenamiento: 0.889..  Pérdida de validación: 0.683..  Exactitud de validación: 0.760
# Epoch: 2/3..  Pérdida de entrenamiento: 0.806..  Pérdida de validación: 0.682..  Exactitud de validación: 0.760
# Epoch: 2/3..  Pérdida de entrenamiento: 0.879..  Pérdida de validación: 0.683..  Exactitud de validación: 0.764
# Epoch: 2/3..  Pérdida de entrenamiento: 0.943..  Pérdida de validación: 0.683..  Exactitud de validación: 0.765
# Epoch: 2/3..  Pérdida de entrenamiento: 0.830..  Pérdida de validación: 0.683..  Exactitud de validación: 0.762
# Epoch: 2/3..  Pérdida de entrenamiento: 0.813..  Pérdida de validación: 0.677..  Exactitud de validación: 0.765
# Epoch: 2/3..  Pérdida de entrenamiento: 0.810..  Pérdida de validación: 0.675..  Exactitud de validación: 0.764
# Epoch: 2/3..  Pérdida de entrenamiento: 0.869..  Pérdida de validación: 0.675..  Exactitud de validación: 0.766
# Epoch: 2/3..  Pérdida de entrenamiento: 0.901..  Pérdida de validación: 0.675..  Exactitud de validación: 0.766
# Epoch: 2/3..  Pérdida de entrenamiento: 0.948..  Pérdida de validación: 0.681..  Exactitud de validación: 0.759
# Epoch: 2/3..  Pérdida de entrenamiento: 0.800..  Pérdida de validación: 0.667..  Exactitud de validación: 0.767
# Epoch: 2/3..  Pérdida de entrenamiento: 0.864..  Pérdida de validación: 0.665..  Exactitud de validación: 0.766
# Epoch: 2/3..  Pérdida de entrenamiento: 0.865..  Pérdida de validación: 0.671..  Exactitud de validación: 0.766
# ...
# Epoch: 2/5..  Pérdida de entrenamiento: 0.658..  Pérdida de validación: 0.553..  Exactitud de validación: 0.798
# Epoch: 2/5..  Pérdida de entrenamiento: 0.604..  Pérdida de validación: 0.548..  Exactitud de validación: 0.800
# Epoch: 2/5..  Pérdida de entrenamiento: 0.601..  Pérdida de validación: 0.545..  Exactitud de validación: 0.805
# Epoch: 2/5..  Pérdida de entrenamiento: 0.575..  Pérdida de validación: 0.544..  Exactitud de validación: 0.807
# Epoch: 2/5..  Pérdida de entrenamiento: 0.648..  Pérdida de validación: 0.553..  Exactitud de validación: 0.782
# Epoch: 2/5..  Pérdida de entrenamiento: 0.579..  Pérdida de validación: 0.550..  Exactitud de validación: 0.789
# Epoch: 2/5..  Pérdida de entrenamiento: 0.651..  Pérdida de validación: 0.551..  Exactitud de validación: 0.793
# Epoch: 2/5..  Pérdida de entrenamiento: 0.563..  Pérdida de validación: 0.544..  Exactitud de validación: 0.807
# Epoch: 2/5..  Pérdida de entrenamiento: 0.557..  Pérdida de validación: 0.538..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.688..  Pérdida de validación: 0.547..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.588..  Pérdida de validación: 0.545..  Exactitud de validación: 0.811
# Epoch: 2/5..  Pérdida de entrenamiento: 0.599..  Pérdida de validación: 0.540..  Exactitud de validación: 0.807
# Epoch: 2/5..  Pérdida de entrenamiento: 0.588..  Pérdida de validación: 0.540..  Exactitud de validación: 0.808
# Epoch: 2/5..  Pérdida de entrenamiento: 0.583..  Pérdida de validación: 0.541..  Exactitud de validación: 0.801
# Epoch: 2/5..  Pérdida de entrenamiento: 0.618..  Pérdida de validación: 0.535..  Exactitud de validación: 0.805
# Epoch: 2/5..  Pérdida de entrenamiento: 0.570..  Pérdida de validación: 0.527..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.743..  Pérdida de validación: 0.541..  Exactitud de validación: 0.814
# Epoch: 2/5..  Pérdida de entrenamiento: 0.610..  Pérdida de validación: 0.530..  Exactitud de validación: 0.821
# Epoch: 2/5..  Pérdida de entrenamiento: 0.700..  Pérdida de validación: 0.537..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.578..  Pérdida de validación: 0.539..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.632..  Pérdida de validación: 0.537..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.686..  Pérdida de validación: 0.536..  Exactitud de validación: 0.815
# Epoch: 2/5..  Pérdida de entrenamiento: 0.577..  Pérdida de validación: 0.537..  Exactitud de validación: 0.821
# Epoch: 2/5..  Pérdida de entrenamiento: 0.591..  Pérdida de validación: 0.548..  Exactitud de validación: 0.811
# Epoch: 2/5..  Pérdida de entrenamiento: 0.574..  Pérdida de validación: 0.543..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.536..  Pérdida de validación: 0.534..  Exactitud de validación: 0.818
# Epoch: 2/5..  Pérdida de entrenamiento: 0.681..  Pérdida de validación: 0.543..  Exactitud de validación: 0.815
# Epoch: 2/5..  Pérdida de entrenamiento: 0.735..  Pérdida de validación: 0.550..  Exactitud de validación: 0.817
# Epoch: 2/5..  Pérdida de entrenamiento: 0.582..  Pérdida de validación: 0.552..  Exactitud de validación: 0.814
# Epoch: 2/5..  Pérdida de entrenamiento: 0.654..  Pérdida de validación: 0.546..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.652..  Pérdida de validación: 0.547..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.587..  Pérdida de validación: 0.548..  Exactitud de validación: 0.812
# Epoch: 2/5..  Pérdida de entrenamiento: 0.613..  Pérdida de validación: 0.543..  Exactitud de validación: 0.811
# Epoch: 2/5..  Pérdida de entrenamiento: 0.570..  Pérdida de validación: 0.537..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.583..  Pérdida de validación: 0.540..  Exactitud de validación: 0.804
# Epoch: 2/5..  Pérdida de entrenamiento: 0.644..  Pérdida de validación: 0.553..  Exactitud de validación: 0.790
# Epoch: 2/5..  Pérdida de entrenamiento: 0.579..  Pérdida de validación: 0.544..  Exactitud de validación: 0.804
# Epoch: 2/5..  Pérdida de entrenamiento: 0.565..  Pérdida de validación: 0.545..  Exactitud de validación: 0.803
# Epoch: 2/5..  Pérdida de entrenamiento: 0.603..  Pérdida de validación: 0.547..  Exactitud de validación: 0.798
# Epoch: 2/5..  Pérdida de entrenamiento: 0.638..  Pérdida de validación: 0.549..  Exactitud de validación: 0.801
# Epoch: 2/5..  Pérdida de entrenamiento: 0.680..  Pérdida de validación: 0.545..  Exactitud de validación: 0.813
# Epoch: 2/5..  Pérdida de entrenamiento: 0.616..  Pérdida de validación: 0.541..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.575..  Pérdida de validación: 0.533..  Exactitud de validación: 0.820
# Epoch: 2/5..  Pérdida de entrenamiento: 0.608..  Pérdida de validación: 0.539..  Exactitud de validación: 0.813
# Epoch: 2/5..  Pérdida de entrenamiento: 0.645..  Pérdida de validación: 0.548..  Exactitud de validación: 0.803
# Epoch: 2/5..  Pérdida de entrenamiento: 0.696..  Pérdida de validación: 0.555..  Exactitud de validación: 0.793
# Epoch: 2/5..  Pérdida de entrenamiento: 0.618..  Pérdida de validación: 0.553..  Exactitud de validación: 0.801
# Epoch: 2/5..  Pérdida de entrenamiento: 0.590..  Pérdida de validación: 0.542..  Exactitud de validación: 0.802
# Epoch: 2/5..  Pérdida de entrenamiento: 0.570..  Pérdida de validación: 0.534..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.566..  Pérdida de validación: 0.535..  Exactitud de validación: 0.813
# Epoch: 2/5..  Pérdida de entrenamiento: 0.561..  Pérdida de validación: 0.534..  Exactitud de validación: 0.807
# Epoch: 2/5..  Pérdida de entrenamiento: 0.617..  Pérdida de validación: 0.532..  Exactitud de validación: 0.816
# Epoch: 2/5..  Pérdida de entrenamiento: 0.612..  Pérdida de validación: 0.543..  Exactitud de validación: 0.815
# Epoch: 2/5..  Pérdida de entrenamiento: 0.573..  Pérdida de validación: 0.535..  Exactitud de validación: 0.820
# Epoch: 2/5..  Pérdida de entrenamiento: 0.648..  Pérdida de validación: 0.546..  Exactitud de validación: 0.805
# Epoch: 2/5..  Pérdida de entrenamiento: 0.552..  Pérdida de validación: 0.544..  Exactitud de validación: 0.808
# Epoch: 2/5..  Pérdida de entrenamiento: 0.589..  Pérdida de validación: 0.535..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.590..  Pérdida de validación: 0.533..  Exactitud de validación: 0.808
# Epoch: 2/5..  Pérdida de entrenamiento: 0.610..  Pérdida de validación: 0.530..  Exactitud de validación: 0.809
# Epoch: 2/5..  Pérdida de entrenamiento: 0.572..  Pérdida de validación: 0.534..  Exactitud de validación: 0.814
# Epoch: 2/5..  Pérdida de entrenamiento: 0.587..  Pérdida de validación: 0.531..  Exactitud de validación: 0.817
# Epoch: 2/5..  Pérdida de entrenamiento: 0.564..  Pérdida de validación: 0.541..  Exactitud de validación: 0.810
# Epoch: 3/5..  Pérdida de entrenamiento: 0.630..  Pérdida de validación: 0.536..  Exactitud de validación: 0.815
# Epoch: 3/5..  Pérdida de entrenamiento: 0.579..  Pérdida de validación: 0.537..  Exactitud de validación: 0.811
# Epoch: 3/5..  Pérdida de entrenamiento: 0.606..  Pérdida de validación: 0.529..  Exactitud de validación: 0.820
# Epoch: 3/5..  Pérdida de entrenamiento: 0.534..  Pérdida de validación: 0.529..  Exactitud de validación: 0.817
# Epoch: 3/5..  Pérdida de entrenamiento: 0.608..  Pérdida de validación: 0.530..  Exactitud de validación: 0.808
# Epoch: 3/5..  Pérdida de entrenamiento: 0.628..  Pérdida de validación: 0.539..  Exactitud de validación: 0.804
# Epoch: 3/5..  Pérdida de entrenamiento: 0.650..  Pérdida de validación: 0.544..  Exactitud de validación: 0.808
# Epoch: 3/5..  Pérdida de entrenamiento: 0.684..  Pérdida de validación: 0.546..  Exactitud de validación: 0.814
# Epoch: 3/5..  Pérdida de entrenamiento: 0.603..  Pérdida de validación: 0.549..  Exactitud de validación: 0.812
# Epoch: 3/5..  Pérdida de entrenamiento: 0.572..  Pérdida de validación: 0.548..  Exactitud de validación: 0.798
# Epoch: 3/5..  Pérdida de entrenamiento: 0.596..  Pérdida de validación: 0.546..  Exactitud de validación: 0.802
# Epoch: 3/5..  Pérdida de entrenamiento: 0.605..  Pérdida de validación: 0.540..  Exactitud de validación: 0.801
# Epoch: 3/5..  Pérdida de entrenamiento: 0.706..  Pérdida de validación: 0.537..  Exactitud de validación: 0.805
# Epoch: 3/5..  Pérdida de entrenamiento: 0.583..  Pérdida de validación: 0.537..  Exactitud de validación: 0.812
# Epoch: 3/5..  Pérdida de entrenamiento: 0.661..  Pérdida de validación: 0.538..  Exactitud de validación: 0.815
# Epoch: 3/5..  Pérdida de entrenamiento: 0.605..  Pérdida de validación: 0.538..  Exactitud de validación: 0.820
# Epoch: 3/5..  Pérdida de entrenamiento: 0.640..  Pérdida de validación: 0.535..  Exactitud de validación: 0.816
# Epoch: 3/5..  Pérdida de entrenamiento: 0.566..  Pérdida de validación: 0.541..  Exactitud de validación: 0.803
# Epoch: 3/5..  Pérdida de entrenamiento: 0.683..  Pérdida de validación: 0.539..  Exactitud de validación: 0.809
# Epoch: 3/5..  Pérdida de entrenamiento: 0.558..  Pérdida de validación: 0.534..  Exactitud de validación: 0.811
# Epoch: 3/5..  Pérdida de entrenamiento: 0.529..  Pérdida de validación: 0.521..  Exactitud de validación: 0.821
# Epoch: 3/5..  Pérdida de entrenamiento: 0.652..  Pérdida de validación: 0.535..  Exactitud de validación: 0.807
# Epoch: 3/5..  Pérdida de entrenamiento: 0.610..  Pérdida de validación: 0.536..  Exactitud de validación: 0.817
# Epoch: 3/5..  Pérdida de entrenamiento: 0.576..  Pérdida de validación: 0.536..  Exactitud de validación: 0.823
# Epoch: 3/5..  Pérdida de entrenamiento: 0.562..  Pérdida de validación: 0.535..  Exactitud de validación: 0.816
# Epoch: 3/5..  Pérdida de entrenamiento: 0.599..  Pérdida de validación: 0.533..  Exactitud de validación: 0.817
# Epoch: 3/5..  Pérdida de entrenamiento: 0.617..  Pérdida de validación: 0.531..  Exactitud de validación: 0.819
# Epoch: 3/5..  Pérdida de entrenamiento: 0.542..  Pérdida de validación: 0.531..  Exactitud de validación: 0.823
# Epoch: 3/5..  Pérdida de entrenamiento: 0.581..  Pérdida de validación: 0.528..  Exactitud de validación: 0.824
# Epoch: 3/5..  Pérdida de entrenamiento: 0.587..  Pérdida de validación: 0.527..  Exactitud de validación: 0.819
# Epoch: 3/5..  Pérdida de entrenamiento: 0.541..  Pérdida de validación: 0.525..  Exactitud de validación: 0.820
# Epoch: 3/5..  Pérdida de entrenamiento: 0.585..  Pérdida de validación: 0.532..  Exactitud de validación: 0.818
# Epoch: 3/5..  Pérdida de entrenamiento: 0.547..  Pérdida de validación: 0.537..  Exactitud de validación: 0.814
# Epoch: 3/5..  Pérdida de entrenamiento: 0.578..  Pérdida de validación: 0.532..  Exactitud de validación: 0.822
# Epoch: 3/5..  Pérdida de entrenamiento: 0.591..  Pérdida de validación: 0.540..  Exactitud de validación: 0.802
# Epoch: 3/5..  Pérdida de entrenamiento: 0.619..  Pérdida de validación: 0.540..  Exactitud de validación: 0.797
# Epoch: 3/5..  Pérdida de entrenamiento: 0.579..  Pérdida de validación: 0.538..  Exactitud de validación: 0.805
# Epoch: 3/5..  Pérdida de entrenamiento: 0.700..  Pérdida de validación: 0.546..  Exactitud de validación: 0.800
# Epoch: 3/5..  Pérdida de entrenamiento: 0.565..  Pérdida de validación: 0.541..  Exactitud de validación: 0.795
# Epoch: 3/5..  Pérdida de entrenamiento: 0.672..  Pérdida de validación: 0.543..  Exactitud de validación: 0.800
# Epoch: 3/5..  Pérdida de entrenamiento: 0.625..  Pérdida de validación: 0.545..  Exactitud de validación: 0.797
# Epoch: 3/5..  Pérdida de entrenamiento: 0.509..  Pérdida de validación: 0.541..  Exactitud de validación: 0.798
# Epoch: 3/5..  Pérdida de entrenamiento: 0.552..  Pérdida de validación: 0.537..  Exactitud de validación: 0.793
# Epoch: 3/5..  Pérdida de entrenamiento: 0.672..  Pérdida de validación: 0.540..  Exactitud de validación: 0.794
# Epoch: 3/5..  Pérdida de entrenamiento: 0.705..  Pérdida de validación: 0.549..  Exactitud de validación: 0.784
# Epoch: 3/5..  Pérdida de entrenamiento: 0.587..  Pérdida de validación: 0.542..  Exactitud de validación: 0.794
# Epoch: 3/5..  Pérdida de entrenamiento: 0.602..  Pérdida de validación: 0.540..  Exactitud de validación: 0.801
# Epoch: 3/5..  Pérdida de entrenamiento: 0.572..  Pérdida de validación: 0.542..  Exactitud de validación: 0.807
# Epoch: 3/5..  Pérdida de entrenamiento: 0.580..  Pérdida de validación: 0.531..  Exactitud de validación: 0.813
# Epoch: 3/5..  Pérdida de entrenamiento: 0.492..  Pérdida de validación: 0.529..  Exactitud de validación: 0.819
# Epoch: 3/5..  Pérdida de entrenamiento: 0.589..  Pérdida de validación: 0.532..  Exactitud de validación: 0.821
# Epoch: 3/5..  Pérdida de entrenamiento: 0.624..  Pérdida de validación: 0.538..  Exactitud de validación: 0.816
# Epoch: 3/5..  Pérdida de entrenamiento: 0.559..  Pérdida de validación: 0.540..  Exactitud de validación: 0.806
# Epoch: 3/5..  Pérdida de entrenamiento: 0.575..  Pérdida de validación: 0.541..  Exactitud de validación: 0.808
# Epoch: 3/5..  Pérdida de entrenamiento: 0.638..  Pérdida de validación: 0.545..  Exactitud de validación: 0.803
# Epoch: 3/5..  Pérdida de entrenamiento: 0.607..  Pérdida de validación: 0.559..  Exactitud de validación: 0.785
# Epoch: 3/5..  Pérdida de entrenamiento: 0.522..  Pérdida de validación: 0.547..  Exactitud de validación: 0.800
# Epoch: 3/5..  Pérdida de entrenamiento: 0.569..  Pérdida de validación: 0.539..  Exactitud de validación: 0.808
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6624\2769212712.py in <module>
#       3         configuration[hyper_name] = value
#       4         optimizer, epochs, trainloader, validationloader = get_hyperparameters(configuration = configuration, model = model, trainset = trainset, validationset = validationset)
# ----> 5         train_model(optimizer, epochs, trainloader, validationloader)
#       6         test_loss, test_acurracy = validation(model = model, validationloader = validationloader,  criterion = criterion)
#       7         if test_acurracy > best_accuracy[hyper_name]:
#
# ~\AppData\Local\Temp\ipykernel_6624\2757376001.py in train_model(optimizer, epochs, trainloader, validationloader)
#      29                 # Apagamos los gradientes, reduce memoria y cálculos
#      30                 with torch.no_grad():
# ---> 31                     test_loss, accuracy = validation(model, validationloader, criterion)
#      32
#      33                 print("Epoch: {}/{}.. ".format(e+1, epochs),
#
# ~\AppData\Local\Temp\ipykernel_6624\2697777184.py in validation(model, validationloader, criterion)
#       7         images.resize_(images.shape[0], 784)
#       8
# ----> 9         output = model.forward(images)
#      10         test_loss += criterion(output, labels).item()
#      11
#
# ~\AppData\Local\Temp\ipykernel_6624\476924009.py in forward(self, x)
#      32         # La funció de activación es un RELU combinado con dropout
#      33         for linear in self.hidden_layers:
# ---> 34             x = F.relu(linear(x))
#      35             x = self.dropout(x)
#      36
#
# c:\Users\aaron\miniconda3\envs\pptorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# c:\Users\aaron\miniconda3\envs\pptorch\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 4. Selección del mejor valor:
#
# Analizar los resultados y seleccionar el valor de la tasa de aprendizaje que produce el mejor rendimiento del modelo.

# %% [markdown]
# ### 5. Repetición para otras variables:
#
# Proceder con la siguiente variable (por ejemplo, el número de capas) y repetir el proceso: variar solo esta variable mientras se mantienen constantes todos los demás hiperparámetros, utilizando el mejor valor encontrado para la tasa de aprendizaje. Continuar este proceso para cada variable en la lista.
#
# > TODO: Escribe una tabla con el resultado de cada experimento. Las columnas deben ser: ID, Configuración, Exactitud obtenida.

# %%
import pandas as pd
from IPython.display import display

df_experiments = pd.DataFrame(experiments)
display(df_experiments)

# %% [markdown]
# ## Conclusiones
#
# ¿Cual fue el mejor valor encontrado?
# ¿Cuantas ejecuciones se realizaron?
# ¿Que tiempo tomó realizar todos los experimentos?
